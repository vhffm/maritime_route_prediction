# %%
import pandas as pd
import geopandas as gpd
import movingpandas as mpd
import numpy as np
from datetime import timedelta, datetime
import time
from scipy.sparse import coo_matrix
from shapely.geometry import Point, LineString, MultiLineString
from shapely import ops
import networkx as nx
import matplotlib.pyplot as plt
import neptune
import folium
import pickle
import warnings
import sys

warnings.filterwarnings('ignore')

print("Geopandas has version {}".format(gpd.__version__))
print("Movingpandas has version {}".format(mpd.__version__))
# Out:
# Geopandas has version 0.13.2
# Movingpandas has version 0.17.1

# %%
# add paths for modules
sys.path.append('../src/models')
sys.path.append('../src/visualization')
sys.path.append('../src/features')
# import modules
import visualize
import geometry_utils
from maritime_traffic_network import MaritimeTrafficNetwork

# %%
# load data for network creation
# read data from file
datasize = 'full'
location = 'tromso'
data_date = '202204'
eval_date = '202205'

orig_filename = '../data/processed/'+data_date+'_points_'+location+'_cleaned_meta_'+datasize+'_dualSplit_2.parquet'
gdf = gpd.read_parquet(orig_filename)
# Transform to desired CRS
# 4326 for WGS 84 (global) // 32632 for UTM 32N (Norway)
crs = 32632  # Coordinate reference system
gdf.to_crs(crs, inplace=True)  # Transformation

# %%
# load evaluation data
eval_file = eval_date+'_points_'+location+'_cleaned_meta_full_dualSplit_2'
filename = '../data/processed/' + eval_file + '.parquet'
test_gdf = gpd.read_parquet(filename)
crs = 32632  # Coordinate reference system
test_gdf.to_crs(crs, inplace=True)  # Transformation
all_test_trajectories = mpd.TrajectoryCollection(test_gdf, traj_id_col='mmsi', obj_id_col='mmsi')

# select evaluation data
selection_start = 0
selection_end = len(all_test_trajectories)
selection_step = 3
selection = np.arange(selection_start, selection_end, selection_step)
n_trajectories = len(selection)
mmsis = test_gdf.mmsi.unique()[selection]
test_trajectories = all_test_trajectories.filter('mmsi', mmsis.tolist())

# %%
# load significant points
#sp_gdf = gpd.read_parquet('../data/processed/202204_significant_points_DP10_stavanger_full_UTM.parquet')
#sp_gdf.to_crs(crs, inplace=True)  # Transformation

# %%
# make experiments
vals_ms = [30, 25, 20, 18, 16, 15, 14, 13, 12, 11, 10, 8, 6]
vals_DP = []
vals_v34 = []
vals_v5 = []
vals_max_dist = []
vals_max_angle = []


for i in range (0, len(vals_ms)):
    run = neptune.init_run(
        project="jandrik91/Maritime-Traffic-Network",
        api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxYmQzMjgwZS1jZGYwLTQ2YjktYWNjOS02MjBlZWEzNzUzNDcifQ==",
    )  # your credentials

    network = MaritimeTrafficNetwork(gdf, crs)
    network.get_trajectories_info()
    
    # parameters
    tolerance = 10 # DP tolerance parameter 0.0002
    method = 'HDBSCAN'      # 'DBSCAN' , 'HDBSCAN', 'OPTICS'
    metric = 'mahalanobis'  # 'euclidean', 'mahalanobis', 'haversine'
    min_samples = vals_ms[i]
    min_cluster_size = vals_ms[i]
    eps = 0
    V = np.diag([1, 1, 0.01, 0.01, 1])  # mahalanobis distance parameter matrix V = np.diag([1, 1, 0.01, 0.01, 1])  seems to be good
    max_distance = 20
    max_angle = 45
    merge_stops = True
    merge_stops_speed = 2
    pruning = 1
    model = data_date+'_waypoints_DP' + str(tolerance) + '_' + method + str(min_samples) +'_'+location+'_'+datasize+'_UTM'
    # save hyperparameters
    params = {
        'Data':orig_filename,
        'DP_tolerance':tolerance,
        'clustering_method':method,
        'clustering_metric':metric,
        'clustering_min_samples':min_samples,
        'clustering_min_cluster_size':min_cluster_size,
        'clustering_eps':eps,
        'clustering_metric_V':V,
        'graph_generation_max_distance':max_distance,
        'graph_generation_max_angle':max_angle
    }
    network.set_hyperparameters(params)
    
    # calculate significant turning points using Douglas Peucker algorithm
    network.calc_significant_points_DP(tolerance)
    #network.init_precomputed_significant_points(sp_gdf)
    
    # compute waypoints
    network.calc_waypoints_clustering(method=method, min_samples=min_samples, min_cluster_size=min_cluster_size,
                                      eps=eps, metric=metric, V=V)
    # make graph from waypoints
    network.make_graph_from_waypoints(max_distance=max_distance, max_angle=max_angle)
    
    # merge stop points
    if merge_stops:
        network.merge_stop_points(max_speed=merge_stops_speed)
    
    # prune graph
    network.prune_graph(pruning)

    # evaluate
    all_paths, all_evaluation_results, summary, fig = network.evaluate_graph(test_trajectories)

    # save experiment
    run["model"]=model
    run["algorithm"]='V7.0(SSPD,std)'
    run["n_points"]=len(network.gdf)
    run["n_nodes"]=network.G_pruned.number_of_nodes()
    run["n_edges"]=network.G_pruned.number_of_edges()
    run["n_isolated"]=nx.number_of_isolates(network.G_pruned)
    run["merge_stops"] = merge_stops
    run["merge_stops_speed"] = merge_stops_speed
    run["pruning"] = pruning
    
    params = network.hyperparameters
    params['clustering_metric_V_coord'] = params['clustering_metric_V'][0][0]
    params['clustering_metric_V_cog'] = params['clustering_metric_V'][2][2]
    params['clustering_metric_V_speed'] = params['clustering_metric_V'][4][4]
    run["parameters"] = params
    
    run["test_data"] = {'eval_file':eval_file,
                        'selection_start':selection_start,
                        'selection_end':selection_end,
                        'selection_step':selection_step,
                        'n_trajectories':n_trajectories}
    
    run["plot"].upload(fig)
    run["summary"] = summary
    
    run.stop()
# Out:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-571
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.97 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.79 minutes
# Calculating waypoints with HDBSCAN (min_samples = 8) ...
# Distance metric: mahalanobis
# 2875 clusters detected
# Time elapsed: 5.41 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 2875 (20 isolated)
# Number of edges: 12408
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 13.04 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 2870 (19 isolated)
# Number of edges: 12026
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 18.60 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.013889  0.013889   0.013889          0.013889  0.013889         0.013889
# no_intersects  0.038889  0.000000   0.000000          0.038889  0.000000         0.000000
# success        0.947222  0.947222   0.947222          0.947222  0.947222         0.947222
#
#  ---------------------------
#
# Fraction of NaN results: 0.039
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.963
#
# Mean distance      = 102.85 m
# Median distance    = 48.78 m
# Standard deviation = 187.78 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-571/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-572
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.05 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.95 minutes
# Calculating waypoints with HDBSCAN (min_samples = 9) ...
# Distance metric: mahalanobis
# 2417 clusters detected
# Time elapsed: 7.79 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 2417 (15 isolated)
# Number of edges: 10733
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 10.70 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 2415 (14 isolated)
# Number of edges: 10455
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 17.60 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.002778  0.002778   0.002778          0.002778  0.002778         0.002778
# no_intersects  0.044444  0.000000   0.000000          0.044444  0.000000         0.000000
# success        0.952778  0.952778   0.952778          0.952778  0.952778         0.952778
#
#  ---------------------------
#
# Fraction of NaN results: 0.044
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.963
#
# Mean distance      = 113.35 m
# Median distance    = 53.68 m
# Standard deviation = 195.92 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-572/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-573
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.86 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.74 minutes
# Calculating waypoints with HDBSCAN (min_samples = 10) ...
# Distance metric: mahalanobis
# 2083 clusters detected
# Time elapsed: 5.52 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 2083 (15 isolated)
# Number of edges: 9493
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 10.76 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 2081 (14 isolated)
# Number of edges: 9260
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 19.19 minutes
# Success rates:
#                mmsi  SSPD  distances  fraction_covered  path  path_linestring
# message
# no_intersects  0.05  0.00       0.00              0.05  0.00             0.00
# success        0.95  0.95       0.95              0.95  0.95             0.95
#
#  ---------------------------
#
# Fraction of NaN results: 0.050
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.962
#
# Mean distance      = 115.48 m
# Median distance    = 57.36 m
# Standard deviation = 172.09 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-573/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-574
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.00 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.89 minutes
# Calculating waypoints with HDBSCAN (min_samples = 11) ...
# Distance metric: mahalanobis
# 1817 clusters detected
# Time elapsed: 5.56 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1817 (11 isolated)
# Number of edges: 8383
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 10.17 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1815 (10 isolated)
# Number of edges: 8188
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 17.42 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.055556  0.000000   0.000000          0.055556  0.000000         0.000000
# success        0.944444  0.944444   0.944444          0.944444  0.944444         0.944444
#
#  ---------------------------
#
# Fraction of NaN results: 0.056
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.956
#
# Mean distance      = 122.97 m
# Median distance    = 59.62 m
# Standard deviation = 185.31 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-574/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-575
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.04 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.75 minutes
# Calculating waypoints with HDBSCAN (min_samples = 12) ...
# Distance metric: mahalanobis
# 1587 clusters detected
# Time elapsed: 5.27 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1587 (9 isolated)
# Number of edges: 7442
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 9.47 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1585 (8 isolated)
# Number of edges: 7268
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 15.49 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.055556  0.000000   0.000000          0.055556  0.000000         0.000000
# success        0.944444  0.944444   0.944444          0.944444  0.944444         0.944444
#
#  ---------------------------
#
# Fraction of NaN results: 0.056
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.951
#
# Mean distance      = 130.44 m
# Median distance    = 61.97 m
# Standard deviation = 200.96 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-575/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-576
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.88 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.70 minutes
# Calculating waypoints with HDBSCAN (min_samples = 13) ...
# Distance metric: mahalanobis
# 1411 clusters detected
# Time elapsed: 5.15 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1411 (6 isolated)
# Number of edges: 6740
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.73 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1409 (5 isolated)
# Number of edges: 6589
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 12.77 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.063889  0.000000   0.000000          0.063889  0.000000         0.000000
# success        0.936111  0.936111   0.936111          0.936111  0.936111         0.936111
#
#  ---------------------------
#
# Fraction of NaN results: 0.064
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.950
#
# Mean distance      = 130.08 m
# Median distance    = 63.50 m
# Standard deviation = 192.33 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-576/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-577
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.87 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.72 minutes
# Calculating waypoints with HDBSCAN (min_samples = 14) ...
# Distance metric: mahalanobis
# 1302 clusters detected
# Time elapsed: 5.13 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1302 (5 isolated)
# Number of edges: 6254
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.55 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1301 (4 isolated)
# Number of edges: 6132
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 12.31 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.002778  0.002778   0.002778          0.002778  0.002778         0.002778
# no_intersects  0.061111  0.000000   0.000000          0.061111  0.000000         0.000000
# success        0.936111  0.936111   0.936111          0.936111  0.936111         0.936111
#
#  ---------------------------
#
# Fraction of NaN results: 0.061
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.950
#
# Mean distance      = 139.48 m
# Median distance    = 65.40 m
# Standard deviation = 207.85 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-577/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-578
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.05 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.79 minutes
# Calculating waypoints with HDBSCAN (min_samples = 15) ...
# Distance metric: mahalanobis
# 1189 clusters detected
# Time elapsed: 5.47 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1189 (4 isolated)
# Number of edges: 5754
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.90 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1188 (3 isolated)
# Number of edges: 5651
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 13.54 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.008333  0.008333   0.008333          0.008333  0.008333         0.008333
# no_intersects  0.058333  0.000000   0.000000          0.058333  0.000000         0.000000
# success        0.933333  0.933333   0.933333          0.933333  0.933333         0.933333
#
#  ---------------------------
#
# Fraction of NaN results: 0.058
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.938
#
# Mean distance      = 145.92 m
# Median distance    = 67.04 m
# Standard deviation = 213.01 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-578/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-579
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.98 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.76 minutes
# Calculating waypoints with HDBSCAN (min_samples = 16) ...
# Distance metric: mahalanobis
# 1091 clusters detected
# Time elapsed: 5.44 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1091 (4 isolated)
# Number of edges: 5290
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.67 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1090 (3 isolated)
# Number of edges: 5191
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 11.44 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.058333  0.000000   0.000000          0.058333  0.000000         0.000000
# success        0.941667  0.941667   0.941667          0.941667  0.941667         0.941667
#
#  ---------------------------
#
# Fraction of NaN results: 0.058
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.941
#
# Mean distance      = 145.86 m
# Median distance    = 66.42 m
# Standard deviation = 226.11 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-579/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-580
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.91 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.75 minutes
# Calculating waypoints with HDBSCAN (min_samples = 18) ...
# Distance metric: mahalanobis
# 945 clusters detected
# Time elapsed: 5.20 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 945 (3 isolated)
# Number of edges: 4672
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.64 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 945 (3 isolated)
# Number of edges: 4580
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 10.18 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.066667  0.000000   0.000000          0.066667  0.000000         0.000000
# success        0.933333  0.933333   0.933333          0.933333  0.933333         0.933333
#
#  ---------------------------
#
# Fraction of NaN results: 0.067
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.931
#
# Mean distance      = 151.98 m
# Median distance    = 70.52 m
# Standard deviation = 233.04 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-580/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-581
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.04 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.81 minutes
# Calculating waypoints with HDBSCAN (min_samples = 20) ...
# Distance metric: mahalanobis
# 816 clusters detected
# Time elapsed: 5.44 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 816 (4 isolated)
# Number of edges: 3945
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.54 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 816 (4 isolated)
# Number of edges: 3860
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 8.68 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.080556  0.000000   0.000000          0.080556  0.000000         0.000000
# success        0.919444  0.919444   0.919444          0.919444  0.919444         0.919444
#
#  ---------------------------
#
# Fraction of NaN results: 0.081
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.920
#
# Mean distance      = 152.21 m
# Median distance    = 72.19 m
# Standard deviation = 241.50 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-581/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-582
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.91 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.81 minutes
# Calculating waypoints with HDBSCAN (min_samples = 25) ...
# Distance metric: mahalanobis
# 636 clusters detected
# Time elapsed: 5.24 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 636 (3 isolated)
# Number of edges: 2844
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.15 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 636 (3 isolated)
# Number of edges: 2780
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 6.62 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.002778  0.002778   0.002778          0.002778  0.002778         0.002778
# no_intersects  0.108333  0.000000   0.000000          0.108333  0.000000         0.000000
# success        0.888889  0.888889   0.888889          0.888889  0.888889         0.888889
#
#  ---------------------------
#
# Fraction of NaN results: 0.108
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.921
#
# Mean distance      = 164.59 m
# Median distance    = 79.50 m
# Standard deviation = 241.05 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-582/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-583
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.89 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.75 minutes
# Calculating waypoints with HDBSCAN (min_samples = 30) ...
# Distance metric: mahalanobis
# 531 clusters detected
# Time elapsed: 5.13 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 531 (3 isolated)
# Number of edges: 2217
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 7.88 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 531 (3 isolated)
# Number of edges: 2168
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.31 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.002778  0.002778   0.002778          0.002778  0.002778         0.002778
# no_intersects  0.113889  0.000000   0.000000          0.113889  0.000000         0.000000
# success        0.883333  0.883333   0.883333          0.883333  0.883333         0.883333
#
#  ---------------------------
#
# Fraction of NaN results: 0.114
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.901
#
# Mean distance      = 173.41 m
# Median distance    = 82.42 m
# Standard deviation = 252.05 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-583/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-584
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.94 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.78 minutes
# Calculating waypoints with HDBSCAN (min_samples = 35) ...
# Distance metric: mahalanobis
# 465 clusters detected
# Time elapsed: 5.18 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 465 (3 isolated)
# Number of edges: 1917
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 7.47 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 465 (3 isolated)
# Number of edges: 1879
# ------------------------
# Evaluating graph on 360 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.85 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# no_intersects  0.111111  0.000000   0.000000          0.111111  0.000000         0.000000
# success        0.888889  0.888889   0.888889          0.888889  0.888889         0.888889
#
#  ---------------------------
#
# Fraction of NaN results: 0.111
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.910
#
# Mean distance      = 180.38 m
# Median distance    = 84.45 m
# Standard deviation = 262.40 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-584/metadata

# %%
# save network as pickle object
#fileObj = open('../data/interim/202204_waypoints_DP10_HDBSCAN15_stavanger_full_UTM.obj', 'wb')
#pickle.dump(network, fileObj)
#fileObj.close()
