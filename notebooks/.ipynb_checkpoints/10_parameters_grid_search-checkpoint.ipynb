# %%
import pandas as pd
import geopandas as gpd
import movingpandas as mpd
import numpy as np
from datetime import timedelta, datetime
import time
from scipy.sparse import coo_matrix
from shapely.geometry import Point, LineString, MultiLineString
from shapely import ops
import networkx as nx
import matplotlib.pyplot as plt
import neptune
import folium
import pickle
import warnings
import sys

warnings.filterwarnings('ignore')

print("Geopandas has version {}".format(gpd.__version__))
print("Movingpandas has version {}".format(mpd.__version__))
# Out:
# Geopandas has version 0.13.2
# Movingpandas has version 0.17.1

# %%
# add paths for modules
sys.path.append('../src/models')
sys.path.append('../src/visualization')
sys.path.append('../src/features')
# import modules
import visualize
import geometry_utils
from maritime_traffic_network import MaritimeTrafficNetwork

# %%
# load data for network creation
# read data from file
datasize = 'full'
location = 'tromso'
data_date = '202204'
eval_date = '202205'

orig_filename = '../data/processed/'+data_date+'_points_'+location+'_cleaned_meta_'+datasize+'_dualSplit_2.parquet'
gdf = gpd.read_parquet(orig_filename)
# Transform to desired CRS
# 4326 for WGS 84 (global) // 32632 for UTM 32N (Norway)
crs = 32632  # Coordinate reference system
gdf.to_crs(crs, inplace=True)  # Transformation

# %%
# load evaluation data
eval_file = eval_date+'_points_'+location+'_cleaned_meta_full_dualSplit_2'
filename = '../data/processed/' + eval_file + '.parquet'
test_gdf = gpd.read_parquet(filename)
crs = 32632  # Coordinate reference system
test_gdf.to_crs(crs, inplace=True)  # Transformation
all_test_trajectories = mpd.TrajectoryCollection(test_gdf, traj_id_col='mmsi', obj_id_col='mmsi')

# select evaluation data
selection_start = 1
selection_end = len(all_test_trajectories)
selection_step = 3
selection = np.arange(selection_start, selection_end, selection_step)
n_trajectories = len(selection)
mmsis = test_gdf.mmsi.unique()[selection]
test_trajectories = all_test_trajectories.filter('mmsi', mmsis.tolist())

# %%
# load significant points
#sp_gdf = gpd.read_parquet('../data/processed/202204_significant_points_DP10_stavanger_full_UTM.parquet')
#sp_gdf.to_crs(crs, inplace=True)  # Transformation

# %%
# make experiments
vals_ms = [30, 25, 20, 18, 16, 15, 14, 13, 12, 11, 10, 9, 8, 7, 6]
vals_DP = []
vals_v34 = []
vals_v5 = []
vals_max_dist = []
vals_max_angle = []


for i in range (0, len(vals_ms)):
    run = neptune.init_run(
        project="jandrik91/Maritime-Traffic-Network",
        api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxYmQzMjgwZS1jZGYwLTQ2YjktYWNjOS02MjBlZWEzNzUzNDcifQ==",
    )  # your credentials

    network = MaritimeTrafficNetwork(gdf, crs)
    network.get_trajectories_info()
    
    # parameters
    tolerance = 10 # DP tolerance parameter 0.0002
    method = 'HDBSCAN'      # 'DBSCAN' , 'HDBSCAN', 'OPTICS'
    metric = 'mahalanobis'  # 'euclidean', 'mahalanobis', 'haversine'
    min_samples = vals_ms[i]
    min_cluster_size = vals_ms[i]
    eps = 0
    V = np.diag([1, 1, 0.01, 0.01, 5e-4])  # mahalanobis distance parameter matrix V = np.diag([1, 1, 0.01, 0.01, 5e-4])  seems to be good
    max_distance = 10
    max_angle = 45
    merge_stops = True
    merge_stops_speed = 2
    pruning = 1
    model = data_date+'_waypoints_DP' + str(tolerance) + '_' + method + str(min_samples) +'_'+location+'_'+datasize+'_UTM'
    # save hyperparameters
    params = {
        'Data':orig_filename,
        'DP_tolerance':tolerance,
        'clustering_method':method,
        'clustering_metric':metric,
        'clustering_min_samples':min_samples,
        'clustering_min_cluster_size':min_cluster_size,
        'clustering_eps':eps,
        'clustering_metric_V':V,
        'graph_generation_max_distance':max_distance,
        'graph_generation_max_angle':max_angle
    }
    network.set_hyperparameters(params)
    
    # calculate significant turning points using Douglas Peucker algorithm
    network.calc_significant_points_DP(tolerance)
    #network.init_precomputed_significant_points(sp_gdf)
    
    # compute waypoints
    network.calc_waypoints_clustering(method=method, min_samples=min_samples, min_cluster_size=min_cluster_size,
                                      eps=eps, metric=metric, V=V)
    # make graph from waypoints
    network.make_graph_from_waypoints(max_distance=max_distance, max_angle=max_angle)
    
    # merge stop points
    if merge_stops:
        network.merge_stop_points(max_speed=merge_stops_speed)
    
    # prune graph
    network.prune_graph(pruning)

    # evaluate
    all_paths, all_evaluation_results, summary, fig = network.evaluate_graph(test_trajectories)

    # save experiment
    run["model"]=model
    run["algorithm"]='V6.0(SSPD)'
    run["n_points"]=len(network.gdf)
    run["n_nodes"]=network.G_pruned.number_of_nodes()
    run["n_edges"]=network.G_pruned.number_of_edges()
    run["n_isolated"]=nx.number_of_isolates(network.G_pruned)
    run["merge_stops"] = merge_stops
    run["merge_stops_speed"] = merge_stops_speed
    run["pruning"] = pruning
    
    params = network.hyperparameters
    params['clustering_metric_V_coord'] = params['clustering_metric_V'][0][0]
    params['clustering_metric_V_cog'] = params['clustering_metric_V'][2][2]
    params['clustering_metric_V_speed'] = params['clustering_metric_V'][4][4]
    run["parameters"] = params
    
    run["test_data"] = {'eval_file':eval_file,
                        'selection_start':selection_start,
                        'selection_end':selection_end,
                        'selection_step':selection_step,
                        'n_trajectories':n_trajectories}
    
    run["plot"].upload(fig)
    run["summary"] = summary
    
    run.stop()
# Out:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-353
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.78 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.61 minutes
# Calculating waypoints with HDBSCAN (min_samples = 40) ...
# Distance metric: mahalanobis
# 349 clusters detected
# Time elapsed: 4.98 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 349 (3 isolated)
# Number of edges: 1337
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 6.71 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 349 (3 isolated)
# Number of edges: 1307
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 4.14 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.021008   0.014706     0.014706  0.014706   0.021008          0.021008
# no_intersects  0.130252   0.000000     0.000000  0.000000   0.000000          0.130252
# success        0.848739   0.848739     0.848739  0.848739   0.848739          0.848739
#
#  ---------------------------
#
# Fraction of NaN results: 0.137
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.850
#
# Mean distance      = 321.52 m
# Median distance    = 106.20 m
# Standard deviation = 844.28 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-353/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-354
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.76 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.60 minutes
# Calculating waypoints with HDBSCAN (min_samples = 35) ...
# Distance metric: mahalanobis
# 414 clusters detected
# Time elapsed: 4.97 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 414 (3 isolated)
# Number of edges: 1620
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 6.93 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 414 (3 isolated)
# Number of edges: 1584
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 4.93 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.012605   0.010504     0.010504  0.010504   0.012605          0.012605
# no_intersects  0.117647   0.000000     0.000000  0.000000   0.000000          0.117647
# no_path        0.004202   0.000000     0.000000  0.000000   0.000000          0.004202
# success        0.865546   0.865546     0.865546  0.865546   0.865546          0.865546
#
#  ---------------------------
#
# Fraction of NaN results: 0.124
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.840
#
# Mean distance      = 269.88 m
# Median distance    = 98.87 m
# Standard deviation = 607.37 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-354/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-355
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.78 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.61 minutes
# Calculating waypoints with HDBSCAN (min_samples = 30) ...
# Distance metric: mahalanobis
# 486 clusters detected
# Time elapsed: 4.98 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 486 (3 isolated)
# Number of edges: 2100
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 6.95 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 486 (3 isolated)
# Number of edges: 2049
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 7.07 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.021008   0.012605     0.012605  0.012605   0.021008          0.021008
# no_intersects  0.107143   0.000000     0.000000  0.000000   0.000000          0.107143
# no_path        0.002101   0.000000     0.000000  0.000000   0.000000          0.002101
# success        0.869748   0.869748     0.869748  0.869748   0.869748          0.869748
#
#  ---------------------------
#
# Fraction of NaN results: 0.118
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.869
#
# Mean distance      = 302.80 m
# Median distance    = 97.32 m
# Standard deviation = 728.76 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-355/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-356
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.75 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.60 minutes
# Calculating waypoints with HDBSCAN (min_samples = 25) ...
# Distance metric: mahalanobis
# 578 clusters detected
# Time elapsed: 5.00 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 578 (3 isolated)
# Number of edges: 2609
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 6.97 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 578 (3 isolated)
# Number of edges: 2557
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 11.50 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.018908   0.012605     0.012605  0.012605   0.018908          0.018908
# no_intersects  0.098739   0.000000     0.000000  0.000000   0.000000          0.098739
# no_path        0.004202   0.000000     0.000000  0.000000   0.000000          0.004202
# success        0.878151   0.878151     0.878151  0.878151   0.878151          0.878151
#
#  ---------------------------
#
# Fraction of NaN results: 0.109
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.892
#
# Mean distance      = 277.47 m
# Median distance    = 94.40 m
# Standard deviation = 615.00 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-356/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-357
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.75 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.61 minutes
# Calculating waypoints with HDBSCAN (min_samples = 20) ...
# Distance metric: mahalanobis
# 750 clusters detected
# Time elapsed: 4.97 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 750 (4 isolated)
# Number of edges: 3640
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 7.23 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 750 (4 isolated)
# Number of edges: 3575
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 13.83 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.027311   0.016807     0.016807  0.016807   0.027311          0.027311
# no_intersects  0.079832   0.000000     0.000000  0.000000   0.000000          0.079832
# no_path        0.004202   0.000000     0.000000  0.000000   0.000000          0.004202
# success        0.888655   0.888655     0.888655  0.888655   0.888655          0.888655
#
#  ---------------------------
#
# Fraction of NaN results: 0.095
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.911
#
# Mean distance      = 259.44 m
# Median distance    = 86.82 m
# Standard deviation = 644.11 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-357/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-358
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.76 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.60 minutes
# Calculating waypoints with HDBSCAN (min_samples = 18) ...
# Distance metric: mahalanobis
# 837 clusters detected
# Time elapsed: 4.97 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 837 (3 isolated)
# Number of edges: 4021
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 7.70 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 837 (3 isolated)
# Number of edges: 3955
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 14.51 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.027311   0.018908     0.018908  0.018908   0.027311          0.027311
# no_intersects  0.079832   0.000000     0.000000  0.000000   0.000000          0.079832
# no_path        0.004202   0.000000     0.000000  0.000000   0.000000          0.004202
# success        0.888655   0.888655     0.888655  0.888655   0.888655          0.888655
#
#  ---------------------------
#
# Fraction of NaN results: 0.092
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.915
#
# Mean distance      = 285.85 m
# Median distance    = 88.26 m
# Standard deviation = 757.24 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-358/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-359
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.92 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.74 minutes
# Calculating waypoints with HDBSCAN (min_samples = 16) ...
# Distance metric: mahalanobis
# 982 clusters detected
# Time elapsed: 5.32 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 982 (4 isolated)
# Number of edges: 4847
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.15 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 981 (3 isolated)
# Number of edges: 4759
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 19.11 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.058824   0.048319     0.048319  0.048319   0.058824          0.058824
# no_intersects  0.065126   0.000000     0.000000  0.000000   0.000000          0.065126
# success        0.876050   0.876050     0.876050  0.876050   0.876050          0.876050
#
#  ---------------------------
#
# Fraction of NaN results: 0.076
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.921
#
# Mean distance      = 282.93 m
# Median distance    = 88.55 m
# Standard deviation = 801.06 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-359/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-360
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.97 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.74 minutes
# Calculating waypoints with HDBSCAN (min_samples = 15) ...
# Distance metric: mahalanobis
# 1082 clusters detected
# Time elapsed: 5.84 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1082 (4 isolated)
# Number of edges: 5410
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 10.12 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1081 (3 isolated)
# Number of edges: 5325
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 26.01 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.031513   0.023109     0.023109  0.023109   0.031513          0.031513
# no_intersects  0.065126   0.000000     0.000000  0.000000   0.000000          0.065126
# success        0.903361   0.903361     0.903361  0.903361   0.903361          0.903361
#
#  ---------------------------
#
# Fraction of NaN results: 0.074
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.934
#
# Mean distance      = 308.16 m
# Median distance    = 85.73 m
# Standard deviation = 877.81 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-360/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-361
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.86 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 2.27 minutes
# Calculating waypoints with HDBSCAN (min_samples = 14) ...
# Distance metric: mahalanobis
# 1173 clusters detected
# Time elapsed: 6.41 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1173 (4 isolated)
# Number of edges: 5752
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 13.38 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1171 (2 isolated)
# Number of edges: 5662
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 33.06 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.029412   0.023109     0.023109  0.023109   0.029412          0.029412
# no_intersects  0.056723   0.000000     0.000000  0.000000   0.000000          0.056723
# success        0.913866   0.913866     0.913866  0.913866   0.913866          0.913866
#
#  ---------------------------
#
# Fraction of NaN results: 0.063
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.938
#
# Mean distance      = 274.68 m
# Median distance    = 87.18 m
# Standard deviation = 789.92 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-361/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-362
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.96 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 2.58 minutes
# Calculating waypoints with HDBSCAN (min_samples = 13) ...
# Distance metric: mahalanobis
# 1271 clusters detected
# Time elapsed: 6.43 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1271 (4 isolated)
# Number of edges: 6234
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 13.21 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1268 (2 isolated)
# Number of edges: 6128
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 30.15 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.029412   0.023109     0.023109  0.023109   0.029412          0.029412
# no_intersects  0.060924   0.000000     0.000000  0.000000   0.000000          0.060924
# success        0.909664   0.909664     0.909664  0.909664   0.909664          0.909664
#
#  ---------------------------
#
# Fraction of NaN results: 0.067
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.943
#
# Mean distance      = 331.96 m
# Median distance    = 84.52 m
# Standard deviation = 1041.36 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 7 operations to synchronize with Neptune. Do not kill this process.
# All 7 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-362/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-363
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 2.50 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 2.34 minutes
# Calculating waypoints with HDBSCAN (min_samples = 12) ...
# Distance metric: mahalanobis
# 1409 clusters detected
# Time elapsed: 6.36 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1409 (5 isolated)
# Number of edges: 6891
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 13.01 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1407 (4 isolated)
# Number of edges: 6770
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 28.81 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.027311   0.021008     0.021008  0.021008   0.027311          0.027311
# no_intersects  0.056723   0.000000     0.000000  0.000000   0.000000          0.056723
# success        0.915966   0.915966     0.915966  0.915966   0.915966          0.915966
#
#  ---------------------------
#
# Fraction of NaN results: 0.063
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.945
#
# Mean distance      = 293.69 m
# Median distance    = 81.45 m
# Standard deviation = 910.13 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-363/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-364
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.79 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.61 minutes
# Calculating waypoints with HDBSCAN (min_samples = 11) ...
# Distance metric: mahalanobis
# 1612 clusters detected
# Time elapsed: 5.05 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1612 (6 isolated)
# Number of edges: 7727
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.56 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1610 (5 isolated)
# Number of edges: 7594
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 23.66 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.037815   0.031513     0.031513  0.031513   0.037815          0.037815
# no_intersects  0.050420   0.000000     0.000000  0.000000   0.000000          0.050420
# success        0.911765   0.911765     0.911765  0.911765   0.911765          0.911765
#
#  ---------------------------
#
# Fraction of NaN results: 0.057
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.948
#
# Mean distance      = 327.35 m
# Median distance    = 83.17 m
# Standard deviation = 931.02 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-364/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-365
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.75 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.63 minutes
# Calculating waypoints with HDBSCAN (min_samples = 10) ...
# Distance metric: mahalanobis
# 1850 clusters detected
# Time elapsed: 5.07 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 1850 (9 isolated)
# Number of edges: 8826
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 8.98 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1848 (8 isolated)
# Number of edges: 8659
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 24.76 minutes
# Success rates:
#                    mmsi  mean_dist  median_dist  max_dist  distances  fraction_covered
# message
# attempt        0.031513   0.027311     0.027311  0.027311   0.031513          0.031513
# no_intersects  0.042017   0.000000     0.000000  0.000000   0.000000          0.042017
# no_path        0.002101   0.000000     0.000000  0.000000   0.000000          0.002101
# success        0.924370   0.924370     0.924370  0.924370   0.924370          0.924370
#
#  ---------------------------
#
# Fraction of NaN results: 0.048
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.945
#
# Mean distance      = 371.14 m
# Median distance    = 86.16 m
# Standard deviation = 1140.24 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-365/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-366
# Number of AIS messages: 2173821
# Number of trajectories: 7184
# Coordinate Reference System (CRS): EPSG:32632
# Calculating significant turning points with Douglas Peucker algorithm (tolerance = 10) ...
# Number of significant points detected: 181786 (8.36% of AIS messages)
# Time elapsed: 1.76 minutes
# Adding course over ground before and after each turn ...
# Done. Time elapsed: 1.61 minutes
# Calculating waypoints with HDBSCAN (min_samples = 9) ...
# Distance metric: mahalanobis
# 2203 clusters detected
# Time elapsed: 5.11 minutes
# Constructing maritime traffic network graph from waypoints and trajectories...
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done!
# ------------------------
# Unpruned Graph:
# Number of nodes: 2203 (14 isolated)
# Number of edges: 10235
# Network is (weakly) connected: False
# ------------------------
# Time elapsed: 9.63 minutes
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 2201 (13 isolated)
# Number of edges: 10017
# ------------------------
# Evaluating graph on 476 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 66
#      63 network.prune_graph(pruning)
#      65 # evaluate
# ---> 66 all_paths, all_evaluation_results, summary, fig = network.evaluate_graph(test_trajectories)
#      68 # save experiment
#      69 run["model"]=model
#
# File ~/maritime_route_prediction/notebooks/../src/models/maritime_traffic_network.py:822, in evaluate_graph(self, trajectories)
#     820 # 2. passages is empty and orig == dest --> nothing we can do here
#     821 elif ((len(passages) == 0) & (orig_WP == dest_WP)):
# --> 822     passages = []
#     823 # 3. found passages
#     824 else:
#     825     # if the potential start waypoint is not in the list of intersections, but close to the origin of the trajectory, add it to the set of passages
#     826     if ((orig_WP not in passages) & (dist_orig < 100) & (nx.has_path(G, orig_WP, passages[0]))):
#
# File ~/maritime_route_prediction/notebooks/../src/models/maritime_traffic_network.py:566, in MaritimeTrafficNetwork.trajectory_to_path(self, trajectory, verbose)
#     562 dest_WP, idx_dest, dist_dest = geometry_utils.find_dest_WP(points, waypoints)
#     563 #print('Potential start and end point:', orig_WP, dest_WP)
#     564
#     565 ### GET ALL INTERSECTIONS between trajectory and waypoints and a channel around that trajectory that defines the subgraph
# --> 566 passages, G_channel = geometry_utils.find_WP_intersections(points, trajectory, waypoints, G, 1000)
#     567 if verbose: print('Intersections found:', passages)
#     569 # Distinguish three cases
#     570 # 1. passages is empty and orig != dest
#
# File ~/maritime_route_prediction/notebooks/../src/features/geometry_utils.py:229, in find_WP_intersections(points, trajectory, waypoints, G, channel_width)
#     226 passed_wps = close_wps[mask]
#     227 #print(close_wps[['clusterID', 'distance_to_line', 'angle_before', 'angle_after']])
#     228 # ensure correct ordering of waypoint passages
# --> 229 passed_wps.sort_values(by='distance_to_origin', inplace=True)
#     230 passages.extend(passed_wps['clusterID'].tolist())
#     231 passages = list(OrderedDict.fromkeys(passages))
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/pandas/core/frame.py:6968, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6965         return self.copy(deep=None)
#    6967 if is_range_indexer(indexer, len(indexer)):
# -> 6968     result = self.copy(deep=(not inplace and not using_copy_on_write()))
#    6969     if ignore_index:
#    6970         result.index = default_index(len(result))
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/geodataframe.py:1545, in GeoDataFrame.copy(self, deep)
#    1543 @doc(pd.DataFrame)
#    1544 def copy(self, deep=True):
# -> 1545     copied = super().copy(deep=deep)
#    1546     if type(copied) is pd.DataFrame:
#    1547         copied.__class__ = GeoDataFrame
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/pandas/core/generic.py:6687, in NDFrame.copy(self, deep)
#    6685 data = self._mgr.copy(deep=deep)
#    6686 self._clear_item_cache()
# -> 6687 return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6688     self, method="copy"
#    6689 )
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/pandas/core/frame.py:649, in DataFrame._constructor_from_mgr(self, mgr, axes)
#     647 else:
#     648     assert axes is mgr.axes
# --> 649     return self._constructor(df, copy=False)
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/geodataframe.py:29, in _geodataframe_constructor_with_fallback(*args, **kwargs)
#      23 def _geodataframe_constructor_with_fallback(*args, **kwargs):
#      24     """
#      25     A flexible constructor for GeoDataFrame._constructor, which falls back
#      26     to returning a DataFrame (if a certain operation does not preserve the
#      27     geometry column)
#      28     """
# ---> 29     df = GeoDataFrame(*args, **kwargs)
#      30     geometry_cols_mask = df.dtypes == "geometry"
#      31     if len(geometry_cols_mask) == 0 or geometry_cols_mask.sum() == 0:
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/geodataframe.py:176, in GeoDataFrame.__init__(self, data, geometry, crs, *args, **kwargs)
#     169     if (
#     170         hasattr(self["geometry"].values, "crs")
#     171         and self["geometry"].values.crs
#     172         and crs
#     173         and not self["geometry"].values.crs == crs
#     174     ):
#     175         raise ValueError(crs_mismatch_error)
# --> 176     self["geometry"] = _ensure_geometry(self["geometry"].values, crs)
#     177 except TypeError:
#     178     pass
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/geodataframe.py:1532, in GeoDataFrame.__setitem__(self, key, value)
#    1530     value = [value] * self.shape[0]
#    1531 try:
# -> 1532     crs = getattr(self, "crs", None)
#    1533     value = _ensure_geometry(value, crs=crs)
#    1534     if key == "geometry":
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/geodataframe.py:436, in GeoDataFrame.crs(self)
#     403 """
#     404 The Coordinate Reference System (CRS) represented as a ``pyproj.CRS``
#     405 object.
#    (...)
#     433
#     434 """
#     435 try:
# --> 436     return self.geometry.crs
#     437 except AttributeError:
#     438     raise AttributeError(
#     439         "The CRS attribute of a GeoDataFrame without an active "
#     440         "geometry column is not defined. Use GeoDataFrame.set_geometry "
#     441         "to set the active geometry column."
#     442     )
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/geodataframe.py:220, in GeoDataFrame._get_geometry(self)
#     214 else:
#     215     msg = (
#     216         "You are calling a geospatial method on the GeoDataFrame, "
#     217         f"but the active geometry column ('{self._geometry_column_name}') "
#     218         "is not present. "
#     219     )
# --> 220 geo_cols = list(self.columns[self.dtypes == "geometry"])
#     221 if len(geo_cols) > 0:
#     222     msg += (
#     223         f"\nThere are columns with geometry data type ({geo_cols}), and "
#     224         "you can either set one as the active geometry with "
#     225         'df.set_geometry("name") or access the column as a '
#     226         'GeoSeries (df["name"]) and call the method directly on it.'
#     227     )
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:5389, in Index.__getitem__(self, key)
#    5385     disallow_ndim_indexing(result)
#    5387 # NB: Using _constructor._simple_new would break if MultiIndex
#    5388 #  didn't override __getitem__
# -> 5389 return self._constructor._simple_new(result, name=self._name)
#
# File ~/miniforge3/envs/env_geo/lib/python3.11/site-packages/pandas/core/indexes/base.py:669, in Index._simple_new(cls, values, name, refs)
#     667 else:
#     668     result._references = BlockValuesRefs()
# --> 669 result._references.add_index_reference(result)
#     671 return result
#
# KeyboardInterrupt:

# %%
# save network as pickle object
#fileObj = open('../data/interim/202204_waypoints_DP10_HDBSCAN15_stavanger_full_UTM.obj', 'wb')
#pickle.dump(network, fileObj)
#fileObj.close()
