# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import folium
import warnings
import sys
#warnings.filterwarnings('ignore')

print("Geopandas has version {}".format(gpd.__version__))
# Out:
# Geopandas has version 0.13.2

# %%
# add paths for modules
sys.path.append('../src/visualization')
print(sys.path)

# import modules
import visualize
# Out:
# ['/Users/janhendrikwebert/maritime_route_prediction/notebooks', '/Users/janhendrikwebert/miniforge3/envs/env_geo/lib/python311.zip', '/Users/janhendrikwebert/miniforge3/envs/env_geo/lib/python3.11', '/Users/janhendrikwebert/miniforge3/envs/env_geo/lib/python3.11/lib-dynload', '', '/Users/janhendrikwebert/miniforge3/envs/env_geo/lib/python3.11/site-packages', '../src/visualization']

# %%
# read data from file
filename = '../data/raw/AIS_04-09_2022/ais_202204.csv'
df = pd.read_csv(filename, delimiter=';', decimal='.')

# %%
# convert to geopandas df
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat), crs="EPSG:4326")
df = []  # free memory

# %%
gdf.info()  # print information about loaded data
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 14052976 entries, 0 to 14052975
# Data columns (total 12 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   mmsi           int64
#  1   imo_nr         int64
#  2   length         int64
#  3   date_time_utc  object
#  4   lon            float64
#  5   lat            float64
#  6   sog            float64
#  7   cog            float64
#  8   true_heading   int64
#  9   nav_status     int64
#  10  message_nr     int64
#  11  geometry       geometry
# dtypes: float64(4), geometry(1), int64(6), object(1)
# memory usage: 1.3+ GB

# %%
gdf.head()
# Out:
#         mmsi   imo_nr  length        date_time_utc      lon      lat   sog  \
# 0  209989000  9235505      90  2022-04-01 06:30:21  4.62360  59.5881  10.0
# 1  209989000  9235505      90  2022-04-01 06:30:31  4.62367  59.5877   9.7
# 2  209989000  9235505      90  2022-04-01 06:30:40  4.62375  59.5873   9.9
# 3  209989000  9235505      90  2022-04-01 06:30:50  4.62384  59.5868   9.8
# 4  209989000  9235505      90  2022-04-01 06:31:10  4.62402  59.5859   9.7
#
#      cog  true_heading  nav_status  message_nr                  geometry
# 0  167.2           174           0           1  POINT (4.62360 59.58810)
# 1  179.6           174           0           1  POINT (4.62367 59.58770)
# 2  173.0           174           0           1  POINT (4.62375 59.58730)
# 3  174.7           174           0           1  POINT (4.62384 59.58680)
# 4  177.4           174           0           1  POINT (4.62402 59.58590)

# %%
# some dataset characteristics
columns = ['mmsi', 'imo_nr', 'nav_status', 'message_nr']
for column in columns:
    print(f'{gdf[column].nunique()} unique {column}')

# print start and stop labels
print('\n')
print(f'Unique nav_status: \n {sorted(gdf.nav_status.unique())}')
print(f'Unique message_nr: \n {sorted(gdf.message_nr.unique())}')

# plot ditribution of mmsi
plt.subplot(1, 1, 1)
gdf.mmsi.hist(bins=gdf.mmsi.nunique())
plt.title('Distribution of MMSIs')
plt.show()
# Out:
# 658 unique mmsi
# 646 unique imo_nr
# 11 unique nav_status
# 4 unique message_nr
#
#
# Unique nav_status:
#  [-99, 0, 1, 2, 3, 5, 6, 7, 8, 9, 15]
# Unique message_nr:
#  [1, 2, 3, 18]

# %%
# plot data (n random points)
n_points = 100  # -1 selects all points
if n_points > 0:
    selection = np.random.randint(0, high=len(gdf), size=n_points)
    map = gdf.iloc[selection].explore(cmap='jet', column='mmsi', name='AIS messages')
else:
    map = gdf.explore(cmap='jet', column='mmsi', name='AIS messages')
# Out:
# /Users/janhendrikwebert/miniforge3/envs/env_geo/lib/python3.11/site-packages/geopandas/explore.py:400: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(gdf[column]):

# %%
# get a bounding box of the geographic area
bbox = visualize.get_bounding_box(gdf)
map = bbox.explore(m=map, color='red', name='bounds')
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98ef699f051ca4880bee98246eb6588d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98ef699f051ca4880bee98246eb6588d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98ef699f051ca4880bee98246eb6588d = L.map(
#                 &quot;map_98ef699f051ca4880bee98246eb6588d&quot;,
#                 {
#                     center: [59.0483, 5.45368],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_98ef699f051ca4880bee98246eb6588d);
#
#
#
#
#
#             var tile_layer_05ece4ab6dcd1e5f4aae770052cdc03d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_98ef699f051ca4880bee98246eb6588d);
#
#
#             map_98ef699f051ca4880bee98246eb6588d.fitBounds(
#                 [[58.4721, 4.6705], [59.6245, 6.23686]],
#                 {}
#             );
#
#
#         function geo_json_c7c92f7f5aa85d569f65e1b4a42a91f2_styler(feature) {
#             switch(feature.id) {
#                 case &quot;10910001&quot;: case &quot;12757665&quot;: case &quot;8243663&quot;:
#                     return {&quot;color&quot;: &quot;#beff39&quot;, &quot;fillColor&quot;: &quot;#beff39&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3361076&quot;: case &quot;5904338&quot;: case &quot;5895417&quot;: case &quot;7185022&quot;: case &quot;2273439&quot;: case &quot;10348149&quot;: case &quot;9898033&quot;: case &quot;1205334&quot;: case &quot;10734259&quot;: case &quot;13464094&quot;: case &quot;10358967&quot;: case &quot;7245543&quot;: case &quot;2196294&quot;: case &quot;5444884&quot;: case &quot;740654&quot;: case &quot;2850722&quot;: case &quot;13015122&quot;: case &quot;6777142&quot;: case &quot;4931798&quot;: case &quot;3796544&quot;: case &quot;3307640&quot;: case &quot;11181546&quot;: case &quot;10324879&quot;: case &quot;3406825&quot;: case &quot;3376444&quot;: case &quot;2801086&quot;: case &quot;9026856&quot;:
#                     return {&quot;color&quot;: &quot;#00b8ff&quot;, &quot;fillColor&quot;: &quot;#00b8ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9701281&quot;:
#                     return {&quot;color&quot;: &quot;#0000df&quot;, &quot;fillColor&quot;: &quot;#0000df&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5578799&quot;: case &quot;11896785&quot;:
#                     return {&quot;color&quot;: &quot;#0000ad&quot;, &quot;fillColor&quot;: &quot;#0000ad&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8146864&quot;: case &quot;875956&quot;: case &quot;10852867&quot;: case &quot;9119906&quot;: case &quot;10859690&quot;: case &quot;11773718&quot;: case &quot;11751319&quot;: case &quot;8672172&quot;: case &quot;6852859&quot;:
#                     return {&quot;color&quot;: &quot;#00bcff&quot;, &quot;fillColor&quot;: &quot;#00bcff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5123845&quot;: case &quot;4106727&quot;:
#                     return {&quot;color&quot;: &quot;#0018ff&quot;, &quot;fillColor&quot;: &quot;#0018ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11410890&quot;:
#                     return {&quot;color&quot;: &quot;#0000a4&quot;, &quot;fillColor&quot;: &quot;#0000a4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2961562&quot;: case &quot;8204666&quot;: case &quot;113
