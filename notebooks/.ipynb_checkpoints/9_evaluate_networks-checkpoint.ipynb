# %%
import pandas as pd
import geopandas as gpd
import movingpandas as mpd
import numpy as np
from datetime import timedelta, datetime
import time
from scipy.sparse import coo_matrix
from shapely.geometry import Point, LineString, MultiLineString
from shapely import ops
import networkx as nx
import matplotlib.pyplot as plt
import folium
import pickle
import warnings
import sys

warnings.filterwarnings('ignore')

print("Geopandas has version {}".format(gpd.__version__))
print("Movingpandas has version {}".format(mpd.__version__))
# Out:
# Geopandas has version 0.13.2
# Movingpandas has version 0.17.1

# %%
# add paths for modules
sys.path.append('../src/models')
sys.path.append('../src/visualization')
sys.path.append('../src/features')
# import modules
import visualize
import geometry_utils
from maritime_traffic_network import MaritimeTrafficNetwork

# %%
# load network from pickle
model = '202204_waypoints_DP10_HDBSCAN12_tromso_full_UTM'
model_path = '../models/networks/' + model + '.obj'
fileObj = open(model_path, 'rb')
network = pickle.load(fileObj)
fileObj.close()

# %%
network.get_trajectories_info()
network.hyperparameters
# Out:
# Number of AIS messages: 1794132
# Number of trajectories: 4666
# Coordinate Reference System (CRS): EPSG:32632
# {'Data': '../../data/processed/202204_points_stavanger_cleaned_meta_2M_dualSplit_2.parquet',
#  'DP_tolerance': 10,
#  'clustering_method': 'HDBSCAN',
#  'clustering_metric': 'mahalanobis',
#  'clustering_min_samples': 13,
#  'clustering_min_cluster_size': 13,
#  'clustering_eps': 0,
#  'clustering_metric_V': array([[1.e+00, 0.e+00, 0.e+00, 0.e+00, 0.e+00],
#         [0.e+00, 1.e+00, 0.e+00, 0.e+00, 0.e+00],
#         [0.e+00, 0.e+00, 1.e-02, 0.e+00, 0.e+00],
#         [0.e+00, 0.e+00, 0.e+00, 1.e-02, 0.e+00],
#         [0.e+00, 0.e+00, 0.e+00, 0.e+00, 5.e-04]]),
#  'graph_generation_max_distance': 10,
#  'graph_generation_max_angle': 45}

# %%
network.prune_graph(1)
merge_stops = True
merge_stops_speed = 2
network.merge_stop_points(max_speed=merge_stops_speed)
pruning = 1
network.prune_graph(pruning)
# Out:
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1220 (4 isolated)
# Number of edges: 4371
# ------------------------

# %%
# load evaluation data
eval_file = '202205_points_tromso_cleaned_meta_full_dualSplit_2'
filename = '../data/processed/' + eval_file + '.parquet'
gdf = gpd.read_parquet(filename)
crs = 32632  # Coordinate reference system
gdf.to_crs(crs, inplace=True)  # Transformation
all_trajectories = mpd.TrajectoryCollection(gdf, traj_id_col='mmsi', obj_id_col='mmsi')

# select evaluation data
selection_start = 0
selection_end = len(all_trajectories)
selection_step = 3
selection = np.arange(selection_start, selection_end, selection_step)
n_trajectories = len(selection)
mmsis = gdf.mmsi.unique()[selection]
trajectories = all_trajectories.filter('mmsi', mmsis.tolist())

# %%
#mmsis = ['258002060_1070_2022-05-22 22:24:23', '258002060_928_2022-05-19 18:03:55']
#trajectories = trajectories.filter('mmsi', mmsis)

# %%
#for trajectory in trajectories:
#    path, eval = network.trajectory_to_path2(trajectory)

# %%
# Generate plot
#map = network.map_graph(pruned=True)
#map = trajectories.to_line_gdf()[['geometry', 'mmsi']].explore(m=map, style_kwds={'weight':1, 'color':'black', 'opacity':0.5}, 
#                                                               name='trajectories')
#map = all_paths.explore(m=map, color='yellow', name='paths')
#folium.LayerControl().add_to(map)

#map

# %%
#map.save('dummy2.html')

# %%
# Save experiment results with neptune
import neptune


run = neptune.init_run(
    project="jandrik91/Maritime-Traffic-Network",
    api_token="eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxYmQzMjgwZS1jZGYwLTQ2YjktYWNjOS02MjBlZWEzNzUzNDcifQ==",
)  # your credentials

# evaluate network
all_paths, all_evaluation_results, summary, fig = network.evaluate_graph(trajectories)

run["model"]=model
run["algorithm"]='V8.0(SSPD)'
run["n_points"]=len(network.gdf)
run["n_nodes"]=network.G_pruned.number_of_nodes()
run["n_edges"]=network.G_pruned.number_of_edges()
run["n_isolated"]=nx.number_of_isolates(network.G_pruned)
run["merge_stops"] = merge_stops
run["merge_stops_speed"] = merge_stops_speed
run["pruning"] = pruning

params = network.hyperparameters
params['clustering_metric_V_coord'] = params['clustering_metric_V'][0][0]
params['clustering_metric_V_cog'] = params['clustering_metric_V'][2][2]
params['clustering_metric_V_speed'] = params['clustering_metric_V'][4][4]
run["parameters"] = params

run["test_data"] = {'eval_file':eval_file,
                    'selection_start':selection_start,
                    'selection_end':selection_end,
                    'selection_step':selection_step,
                    'n_trajectories':n_trajectories}

run["plot"].upload(fig)
run["summary"] = summary

run.stop()
# Out:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-491
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 3075
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 8.95 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.054817  0.054817   0.054817          0.054817  0.054817         0.054817
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.003322  0.000000   0.000000          0.003322  0.000000         0.000000
# success        0.850498  0.850498   0.850498          0.850498  0.850498         0.850498
#
#  ---------------------------
#
# Fraction of NaN results: 0.095
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.885
#
# Mean distance      = 267.59 m
# Median distance    = 97.71 m
# Standard deviation = 528.90 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-491/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-493
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2651
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.73 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.069767  0.069767   0.069767          0.069767  0.069767         0.069767
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.003322  0.000000   0.000000          0.003322  0.000000         0.000000
# success        0.835548  0.835548   0.835548          0.835548  0.835548         0.835548
#
#  ---------------------------
#
# Fraction of NaN results: 0.095
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.885
#
# Mean distance      = 254.42 m
# Median distance    = 96.21 m
# Standard deviation = 508.57 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-493/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-494
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2475
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.62 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.076412  0.076412   0.076412          0.076412  0.076412         0.076412
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.003322  0.000000   0.000000          0.003322  0.000000         0.000000
# success        0.828904  0.828904   0.828904          0.828904  0.828904         0.828904
#
#  ---------------------------
#
# Fraction of NaN results: 0.095
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.885
#
# Mean distance      = 251.25 m
# Median distance    = 93.56 m
# Standard deviation = 514.00 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 7 operations to synchronize with Neptune. Do not kill this process.
# All 7 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-494/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-495
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2381
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.56 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.083056  0.083056   0.083056          0.083056  0.083056         0.083056
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.003322  0.000000   0.000000          0.003322  0.000000         0.000000
# success        0.822259  0.822259   0.822259          0.822259  0.822259         0.822259
#
#  ---------------------------
#
# Fraction of NaN results: 0.095
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.885
#
# Mean distance      = 254.03 m
# Median distance    = 94.97 m
# Standard deviation = 515.43 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-495/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-496
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2305
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.54 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.078073  0.078073   0.078073          0.078073  0.078073         0.078073
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.004983  0.000000   0.000000          0.004983  0.000000         0.000000
# success        0.825581  0.825581   0.825581          0.825581  0.825581         0.825581
#
#  ---------------------------
#
# Fraction of NaN results: 0.096
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.884
#
# Mean distance      = 265.79 m
# Median distance    = 100.40 m
# Standard deviation = 511.73 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-496/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-497
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2280
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 5.27 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.083056  0.083056   0.083056          0.083056  0.083056         0.083056
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.004983  0.000000   0.000000          0.004983  0.000000         0.000000
# success        0.820598  0.820598   0.820598          0.820598  0.820598         0.820598
#
#  ---------------------------
#
# Fraction of NaN results: 0.096
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.884
#
# Mean distance      = 251.62 m
# Median distance    = 99.51 m
# Standard deviation = 489.16 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-497/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-498
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2326
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 4.53 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.089701  0.089701   0.089701          0.089701  0.089701         0.089701
# no_intersects  0.091362  0.000000   0.000000          0.091362  0.000000         0.000000
# no_path        0.004983  0.000000   0.000000          0.004983  0.000000         0.000000
# success        0.813953  0.813953   0.813953          0.813953  0.813953         0.813953
#
#  ---------------------------
#
# Fraction of NaN results: 0.096
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.884
#
# Mean distance      = 259.37 m
# Median distance    = 103.48 m
# Standard deviation = 509.89 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 7 operations to synchronize with Neptune. Do not kill this process.
# All 7 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-498/metadata
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-499
# Pruning...
# ------------------------
# Pruned Graph:
# Number of nodes: 1219 (4 isolated)
# Number of edges: 2598
# ------------------------
# Evaluating graph on 602 trajectories
# Progress: 10%...20%...30%...40%...50%...60%...70%...80%...90%...Done! Time elapsed for evaluation: 3.81 minutes
# Success rates:
#                    mmsi      SSPD  distances  fraction_covered      path  path_linestring
# message
# attempt        0.111296  0.111296   0.111296          0.111296  0.111296         0.111296
# no_intersects  0.093023  0.000000   0.000000          0.093023  0.000000         0.000000
# no_path        0.013289  0.000000   0.000000          0.013289  0.000000         0.000000
# success        0.782392  0.782392   0.782392          0.782392  0.782392         0.782392
#
#  ---------------------------
#
# Fraction of NaN results: 0.106
#
#  ---------------------------
#
# Mean fraction of each trajectory covered by the path on the graph: 0.882
#
# Mean distance      = 256.04 m
# Median distance    = 96.50 m
# Standard deviation = 545.70 m
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 33 operations to synchronize with Neptune. Do not kill this process.
# All 33 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/jandrik91/Maritime-Traffic-Network/e/MAR-499/metadata
